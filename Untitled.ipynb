# %% [markdown]
# # Happy Face

# %%
import cv2 ###pip install opencv-python shift+enter
##pip install opencv-contrib-python fullpackage

# %%
from deepface import DeepFace ##pip install deepface

# %%
img = cv2.imread('happyface3.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:04<00:00,  1.01s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 5.073785053440447e-06,
#    'disgust': 2.0493229668301603e-09,
#    'fear': 4.000004739105069e-07,
#    'happy': 99.72010854242939,
#    'sad': 0.006572146174744973,
#    'surprise': 5.90146456850856e-06,
#    'neutral': 0.27330123355373936},
#   'dominant_emotion': 'happy',
#   'region': {'x': 217, 'y': 102, 'w': 102, 'h': 102},
#   'age': 27,
#   'gender': {'Woman': 0.035695379483513534, 'Man': 99.9643087387085},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.9691263195351553,
#    'indian': 8.602136141189106,
#    'black': 0.31009537153514455,
#    'white': 25.754527792604435,
#    'middle eastern': 47.226416899348315,
#    'latino hispanic': 17.13770283089297},
#   'dominant_race': 'middle eastern'}]

# %%
type(predictions)
# Out:
# list

# %% [markdown]
# #We are trying to draw a rectangle across the face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img,(x, y), (x+w, y+h), (0, 255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Neutral Face

# %%
img = cv2.imread('mayank.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.12it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 18.126700818538666,
#    'disgust': 6.525814910673944e-05,
#    'fear': 3.2834552228450775,
#    'happy': 0.0017809459677664563,
#    'sad': 17.451240122318268,
#    'surprise': 0.001179351511382265,
#    'neutral': 61.13557815551758},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 364, 'y': 508, 'w': 418, 'h': 418},
#   'age': 26,
#   'gender': {'Woman': 0.004715538307209499, 'Man': 99.99527931213379},
#   'dominant_gender': 'Man',
#   'race': {'asian': 18.582531809806824,
#    'indian': 22.85068780183792,
#    'black': 7.0949651300907135,
#    'white': 6.50094598531723,
#    'middle eastern': 4.4547464698553085,
#    'latino hispanic': 40.51612317562103},
#   'dominant_race': 'latino hispanic'}]

# %%
type(predictions)
# Out:
# list

# %% [markdown]
# #For Drawing Rectangle across the face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img,(x, y), (x+w, y+h), (0, 255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Surprise Face

# %%
img = cv2.imread('supriseface.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.09it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.014426684356294572,
#    'disgust': 1.3504850016055059e-08,
#    'fear': 2.0545432344079018,
#    'happy': 0.0065073683799710125,
#    'sad': 0.07344296318478882,
#    'surprise': 97.85062670707703,
#    'neutral': 0.00045732622311334126},
#   'dominant_emotion': 'surprise',
#   'region': {'x': 277, 'y': 111, 'w': 498, 'h': 498},
#   'age': 32,
#   'gender': {'Woman': 0.436753174290061, 'Man': 99.56324696540833},
#   'dominant_gender': 'Man',
#   'race': {'asian': 9.23275575041771,
#    'indian': 15.443180501461029,
#    'black': 10.439814627170563,
#    'white': 20.323295891284943,
#    'middle eastern': 21.485359966754913,
#    'latino hispanic': 23.07559996843338},
#   'dominant_race': 'latino hispanic'}]

# %% [markdown]
# #For Drawing Rectangle across the face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img,(x, y), (x+w, y+h), (0, 255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Fear Face

# %%
img = cv2.imread('mayank1.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.20it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.055143970530480146,
#    'disgust': 5.478333378050593e-05,
#    'fear': 60.29508113861084,
#    'happy': 0.001351218088530004,
#    'sad': 38.426512479782104,
#    'surprise': 6.4806243926796014e-06,
#    'neutral': 1.2218463234603405},
#   'dominant_emotion': 'fear',
#   'region': {'x': 63, 'y': 197, 'w': 803, 'h': 803},
#   'age': 26,
#   'gender': {'Woman': 0.012557150330394506, 'Man': 99.98743534088135},
#   'dominant_gender': 'Man',
#   'race': {'asian': 7.5086720287799835,
#    'indian': 32.25166201591492,
#    'black': 7.96348974108696,
#    'white': 8.247046172618866,
#    'middle eastern': 9.57593247294426,
#    'latino hispanic': 34.45320129394531},
#   'dominant_race': 'latino hispanic'}]

# %% [markdown]
# #For Drawing Rectangle across the face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img,(x, y), (x+w, y+h), (0, 255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Sad Face

# %%
img = cv2.imread('sadface.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.88it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.09094325359910727,
#    'disgust': 0.0001142290557254455,
#    'fear': 1.4257543720304966,
#    'happy': 1.9633551673337024e-06,
#    'sad': 98.3716607093811,
#    'surprise': 1.846841080066497e-06,
#    'neutral': 0.11152444640174508},
#   'dominant_emotion': 'sad',
#   'region': {'x': 212, 'y': 110, 'w': 284, 'h': 284},
#   'age': 30,
#   'gender': {'Woman': 0.2819784916937351, 'Man': 99.71802234649658},
#   'dominant_gender': 'Man',
#   'race': {'asian': 5.679663609246231,
#    'indian': 20.721763117418476,
#    'black': 1.97559439245429,
#    'white': 11.949399825894822,
#    'middle eastern': 13.132669814388144,
#    'latino hispanic': 46.54091277962403},
#   'dominant_race': 'latino hispanic'}]

# %% [markdown]
# #For Drawing Rectangle across the face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

    #Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img,(x, y), (x+w, y+h), (0, 255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
